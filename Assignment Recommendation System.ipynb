# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\indup\Downloads\rec-data\rec-data\movies_metadata.csv")
df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
df.shape
# Out:
# (45466, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %%
df.isna().sum()
# Out:
# adult                        0
# belongs_to_collection    40972
# budget                       0
# genres                       0
# homepage                 37684
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   954
# popularity                   5
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages             6
# status                      87
# tagline                  25054
# title                        6
# video                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %%
df2=pd.read_csv(r"C:\Users\indup\Downloads\rec-data\rec-data\metadata_clean.csv")
df2.head()
# Out:
#                          title                              genres  runtime  \
# 0                    Toy Story   ['animation', 'comedy', 'family']     81.0
# 1                      Jumanji  ['adventure', 'fantasy', 'family']    104.0
# 2             Grumpier Old Men               ['romance', 'comedy']    101.0
# 3            Waiting to Exhale      ['comedy', 'drama', 'romance']    127.0
# 4  Father of the Bride Part II                          ['comedy']    106.0
#
#    vote_average  vote_count  year
# 0           7.7      5415.0  1995
# 1           6.9      2413.0  1995
# 2           6.5        92.0  1995
# 3           6.1        34.0  1995
# 4           5.7       173.0  1995

# %%
df.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['title', 'genres', 'runtime', 'vote_average', 'vote_count', 'year'], dtype='object')

# %%
df2.isna().sum()
# Out:
# title             6
# genres            0
# runtime         263
# vote_average      6
# vote_count        6
# year              0
# dtype: int64

# %%
df.describe()
# Out:
#             revenue       runtime  vote_average    vote_count
# count  4.546000e+04  45203.000000  45460.000000  45460.000000
# mean   1.120935e+07     94.128199      5.618207    109.897338
# std    6.433225e+07     38.407810      1.924216    491.310374
# min    0.000000e+00      0.000000      0.000000      0.000000
# 25%    0.000000e+00     85.000000      5.000000      3.000000
# 50%    0.000000e+00     95.000000      6.000000     10.000000
# 75%    0.000000e+00    107.000000      6.800000     34.000000
# max    2.787965e+09   1256.000000     10.000000  14075.000000

# %%
df2['vote_count'].quantile(0.9)
# Out:
# 160.0

# %%
df_filtered = df2[(df2['runtime'] >= 60) & (df2['runtime'] <= 300)]

# %%
df_filtered = df_filtered[df_filtered['vote_count'] >=160]

# %%
df_filtered
# Out:
#                              title  \
# 0                        Toy Story
# 1                          Jumanji
# 4      Father of the Bride Part II
# 5                             Heat
# 8                     Sudden Death
# ...                            ...
# 45177                      Brice 3
# 45204                   Girls Trip
# 45258                Descendants 2
# 45265                Force Majeure
# 45343   The Visitors: Bastille Day
#
#                                                   genres  runtime  \
# 0                      ['animation', 'comedy', 'family']     81.0
# 1                     ['adventure', 'fantasy', 'family']    104.0
# 4                                             ['comedy']    106.0
# 5               ['action', 'crime', 'drama', 'thriller']    170.0
# 8                    ['action', 'adventure', 'thriller']    106.0
# ...                                                  ...      ...
# 45177                                         ['comedy']     95.0
# ...

# %%
def weightedRating(X, m = 160, c = 5.6):
    v = X['vote_count']
    r = X['vote_average']
    ## compute weighted score
    wt_score = (v/(v+m) * r) + (m/(m+v) * c)
    ##            
    return wt_score

# %%
wt_score = weightedRating(df_filtered)

wt_score
# Out:
# 0        7.639731
# 1        6.819161
# 4        5.651952
# 5        7.535777
# 8        5.547904
#            ...
# 45177    4.950000
# 45204    6.666004
# 45258    6.581571
# 45265    6.337349
# 45343    4.782875
# Length: 4511, dtype: float64

# %%
df_filtered.apply(weightedRating, axis = 1)
# Out:
# 0        7.639731
# 1        6.819161
# 4        5.651952
# 5        7.535777
# 8        5.547904
#            ...
# 45177    4.950000
# 45204    6.666004
# 45258    6.581571
# 45265    6.337349
# 45343    4.782875
# Length: 4511, dtype: float64

# %%
df_filtered['weighted_score'] = df_filtered.apply(weightedRating, axis = 1)

# %%
df_filtered.head()
# Out:
#                          title                                    genres  \
# 0                    Toy Story         ['animation', 'comedy', 'family']
# 1                      Jumanji        ['adventure', 'fantasy', 'family']
# 4  Father of the Bride Part II                                ['comedy']
# 5                         Heat  ['action', 'crime', 'drama', 'thriller']
# 8                 Sudden Death       ['action', 'adventure', 'thriller']
#
#    runtime  vote_average  vote_count  year  weighted_score
# 0     81.0           7.7      5415.0  1995        7.639731
# 1    104.0           6.9      2413.0  1995        6.819161
# 4    106.0           5.7       173.0  1995        5.651952
# 5    170.0           7.7      1886.0  1995        7.535777
# 8    106.0           5.5       174.0  1995        5.547904

# %%
top_10_movies = df_filtered.sort_values('weighted_score', ascending = False).head(10)

# %%
top_10_movies
# Out:
#                              title  \
# 314       The Shawshank Redemption
# 834                  The Godfather
# 10309  Dilwale Dulhania Le Jayenge
# 12481              The Dark Knight
# 2843                    Fight Club
# 292                   Pulp Fiction
# 522               Schindler's List
# 23673                     Whiplash
# 5481                 Spirited Away
# 2211             Life Is Beautiful
#
#                                                 genres  runtime  vote_average  \
# 314                                 ['drama', 'crime']    142.0           8.5
# 834                                 ['drama', 'crime']    175.0           8.5
# 10309                   ['comedy', 'drama', 'romance']    190.0           9.1
# 12481         ['drama', 'action', 'crime', 'thriller']    152.0           8.3
# 2843                                         ['drama']    139.0           8.3
# 292                              ['thriller', 'crime']    154.0           8.3
# ...
